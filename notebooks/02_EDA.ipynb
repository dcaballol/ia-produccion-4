# %%
import pandas as pd

df = pd.read_excel("../plan_de_compras_2025.xlsx")

print("Archivo cargado correctamente")
print("Cantidad de filas y columnas:", df.shape)
# Out:
# Running cells with 'Python 3.12.10' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Paulina Velasquez/AppData/Local/Microsoft/WindowsApps/python3.12.exe" -m pip install ipykernel -U --user --force-reinstall'
